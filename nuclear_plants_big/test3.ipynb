# %%
import pandas as pd
df_large_data = pd.read_csv('nuclear_plants_big_dataset.csv')

# %%
df_large_data.describe()
# Out:
#        Power_range_sensor_1  Power_range_sensor_2  Power_range_sensor_3   \
# count        1000000.000000        1000000.000000         1000000.000000
# mean               6.113553              5.990374               9.245323
# std                3.477260              3.432050               2.804857
# min                0.085102              0.040302               4.382602
# 25%                3.101513              3.017495               6.815725
# 50%                6.114164              5.990977               9.245816
# 75%                9.128331              8.965955              11.677129
# max               12.129796             11.928396              14.098197
#
#        Power_range_sensor_4  Pressure _sensor_1  Pressure _sensor_2  \
# count        1000000.000000      1000000.000000      1000000.000000
# mean               8.263960           28.469297            4.620467
# std                4.677486           16.407012            2.659123
# ...
